# %%
from rdkit import Chem
from rdkit.Chem import Draw

# %% [markdown]
# 38
# 105
# 101
# 150
# 83
# 103

# %%
f38_smiles = 'NC(C)N'
f38_molecule = Chem.MolFromSmiles(f38_smiles)
Draw.MolToImage(f38_molecule)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
f105_smiles = '[*]~[*]~[*]~[*]'
f105_molecule = Chem.MolFromSmiles(f105_smiles)
Draw.MolToImage(f105_molecule)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
f101_smiles = 'C1CCCCCCC1'
f101_molecule = Chem.MolFromSmiles(f101_smiles)
Draw.MolToImage(f101_molecule)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>

# %%
f150_smiles = 'A!A$A!A'
f150_molecule = Chem.MolFromSmiles(f150_smiles)
Draw.MolToImage(f150_molecule)
# Out:
# [16:49:08] SMILES Parse Error: syntax error while parsing: A!A$A!A
# [16:49:08] SMILES Parse Error: Failed parsing SMILES 'A!A$A!A' for input: 'A!A$A!A'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 f150_smiles = 'A!A$A!A'
#       2 f150_molecule = Chem.MolFromSmiles(f150_smiles)
# ----> 3 Draw.MolToImage(f150_molecule)
#
# File /opt/anaconda3/lib/python3.11/site-packages/rdkit/Chem/Draw/__init__.py:233, in MolToImage(mol, size, kekulize, wedgeBonds, fitImage, options, canvas, **kwargs)
#     203 """Returns a PIL image containing a drawing of the molecule
#     204
#     205     ARGUMENTS:
#    (...)
#     230       a PIL Image object
#     231 """
#     232 if not mol:
# --> 233   raise ValueError('Null molecule provided')
#     234 if canvas is not None or not hasattr(rdMolDraw2D, 'MolDraw2DCairo'):
# ...

# %%
f83_smiles = 'QAAAA@1'
f83_molecule = Chem.MolFromSmiles(f83_smiles)
Draw.MolToImage(f83_molecule)
# Out:
# [16:50:02] SMILES Parse Error: syntax error while parsing: QAAAA@1
# [16:50:02] SMILES Parse Error: Failed parsing SMILES 'QAAAA@1' for input: 'QAAAA@1'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 f83_smiles = 'QAAAA@1'
#       2 f83_molecule = Chem.MolFromSmiles(f83_smiles)
# ----> 3 Draw.MolToImage(f83_molecule)
#
# File /opt/anaconda3/lib/python3.11/site-packages/rdkit/Chem/Draw/__init__.py:233, in MolToImage(mol, size, kekulize, wedgeBonds, fitImage, options, canvas, **kwargs)
#     203 """Returns a PIL image containing a drawing of the molecule
#     204
#     205     ARGUMENTS:
#    (...)
#     230       a PIL Image object
#     231 """
#     232 if not mol:
# --> 233   raise ValueError('Null molecule provided')
#     234 if canvas is not None or not hasattr(rdMolDraw2D, 'MolDraw2DCairo'):
# ...

# %%
f103_smiles = '[A]~Cl'
f103_molecule = Chem.MolFromSmiles(f103_smiles)
Draw.MolToImage(f103_molecule)
# Out:
# [16:51:04] SMILES Parse Error: syntax error while parsing: [A]~Cl
# [16:51:04] SMILES Parse Error: Failed parsing SMILES '[A]~Cl' for input: '[A]~Cl'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 3
#       1 f103_smiles = '[A]~Cl'
#       2 f103_molecule = Chem.MolFromSmiles(f103_smiles)
# ----> 3 Draw.MolToImage(f103_molecule)
#
# File /opt/anaconda3/lib/python3.11/site-packages/rdkit/Chem/Draw/__init__.py:233, in MolToImage(mol, size, kekulize, wedgeBonds, fitImage, options, canvas, **kwargs)
#     203 """Returns a PIL image containing a drawing of the molecule
#     204
#     205     ARGUMENTS:
#    (...)
#     230       a PIL Image object
#     231 """
#     232 if not mol:
# --> 233   raise ValueError('Null molecule provided')
#     234 if canvas is not None or not hasattr(rdMolDraw2D, 'MolDraw2DCairo'):
# ...
